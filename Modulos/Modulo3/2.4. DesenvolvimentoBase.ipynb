# %% [markdown]
# ![Captura de tela 2026-03-31 171709.png](data:image/png;base64,...)

# %% [markdown]
# **• Dataset escolhido**
#
# dataset_desempenho_escolar.csv
#
# **Dataset simples com informações de alunos:**
#
# nome
# nota
# frequencia
#
# • **Problema formulado:**
#
# Entender como a frequência dos alunos impacta suas notas e identificar padrões de desempenho escolar.
#
# **Objetivo da análise:**
#
# Investigar se alunos com maior frequência têm melhores notas
#
# Explorar padrões de desempenho
#
# Identificar alunos em risco
#
# Melhorar estratégias de ensino
#
# **• Perguntas norteadoras:**
#
# Como as notas estão distribuídas?
#
# Como a frequência se comporta?
#
# Existe relação entre nota e frequência?
#
# Alunos com maior frequência têm melhores notas?
#
# Qual perfil de aluno tem melhor desempenho?
#
# Existe algum caso fora do padrão que merece atenção?
